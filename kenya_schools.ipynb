# %%
import pandas as pd
import numpy as np

# %%
school=pd.read_csv(r'C:\Users\Admin\OneDrive\Desktop\pydata\Schools_modified.csv')

# %%
school.head()
# Out:
#        X     Y    FID          Name_of_Sc          Level_  Status  \
# 0  36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1  36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2  36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3  36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4  37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL     NaN
#
#                SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# 0  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 1  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 2               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 3               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 4               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
#
#    NoTeaching  NonTeachin     Province  District  Division  Location  \
# 0         0.0         0.0  RIFT VALLEY  KOIBATEK  KISANANA   MOGOTIO
# ...

# %%
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31230 entries, 0 to 31229
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   X            31230 non-null  float64
#  1   Y            31230 non-null  float64
#  2   FID          31230 non-null  int64
#  3   Name_of_Sc   31229 non-null  object
#  4   Level_       31229 non-null  object
#  5   Status       25035 non-null  object
#  6   SchSponsor   31229 non-null  object
#  7   Type1        31229 non-null  object
#  8   Type2        31229 non-null  object
#  9   Type3        31229 non-null  object
#  10  No_Classrm   24969 non-null  float64
#  11  BoysToilet   31229 non-null  float64
#  12  GirlsToilet  31229 non-null  float64
#  13  TeachersTo   31229 non-null  float64
#  14  TotalBoys    24964 non-null  float64
#  15  TotalGirls   24866 non-null  float64
#  16  TotalEnrol   31229 non-null  float64
#  17  GO_KTSC_M    31229 non-null  float64
# ...

# %%
school.isnull()
# Out:
#            X      Y    FID  Name_of_Sc  Level_  Status  SchSponsor  Type1  \
# 0      False  False  False       False   False   False       False  False
# 1      False  False  False       False   False   False       False  False
# 2      False  False  False       False   False   False       False  False
# 3      False  False  False       False   False   False       False  False
# 4      False  False  False       False   False    True       False  False
# ...      ...    ...    ...         ...     ...     ...         ...    ...
# 31225  False  False  False       False   False    True       False  False
# 31226  False  False  False       False   False   False       False  False
# 31227  False  False  False       False   False   False       False  False
# 31228  False  False  False       False   False   False       False  False
# 31229  False  False  False       False   False   False       False  False
#
#        Type2  Type3  ...  OthersF  NoTeaching  NonTeachin  Province  District  \
# ...

# %%
school.notnull()
# Out:
#           X     Y   FID  Name_of_Sc  Level_  Status  SchSponsor  Type1  Type2  \
# 0      True  True  True        True    True    True        True   True   True
# 1      True  True  True        True    True    True        True   True   True
# 2      True  True  True        True    True    True        True   True   True
# 3      True  True  True        True    True    True        True   True   True
# 4      True  True  True        True    True   False        True   True   True
# ...     ...   ...   ...         ...     ...     ...         ...    ...    ...
# 31225  True  True  True        True    True   False        True   True   True
# 31226  True  True  True        True    True    True        True   True   True
# 31227  True  True  True        True    True    True        True   True   True
# 31228  True  True  True        True    True    True        True   True   True
# 31229  True  True  True        True    True    True        True   True   True
#
# ...

# %%
school.isnull().sum()
# Out:
# X                 0
# Y                 0
# FID               0
# Name_of_Sc        1
# Level_            1
# Status         6195
# SchSponsor        1
# Type1             1
# Type2             1
# Type3             1
# No_Classrm     6261
# BoysToilet        1
# GirlsToilet       1
# TeachersTo        1
# TotalBoys      6266
# TotalGirls     6364
# TotalEnrol        1
# GO_KTSC_M         1
# GOK_TSC_F         1
# authorityM        1
# authorityF        1
# PTA_BOG_M         1
# PTA_BOG_F         1
# OthersM           1
# OthersF           1
# NoTeaching        1
# NonTeachin        1
# Province          1
# District          1
# Division          1
# Location          1
# Costituenc        1
# Latitude          1
# Longitude         1
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(school)
# Out:
# <Axes: >

# %%
missing=school.isnull().sum()
total=school.isnull().count()
percentage=missing/total*100
percentage.round(2)
# Out:
# X               0.00
# Y               0.00
# FID             0.00
# Name_of_Sc      0.00
# Level_          0.00
# Status         19.84
# SchSponsor      0.00
# Type1           0.00
# Type2           0.00
# Type3           0.00
# No_Classrm     20.05
# BoysToilet      0.00
# GirlsToilet     0.00
# TeachersTo      0.00
# TotalBoys      20.06
# TotalGirls     20.38
# TotalEnrol      0.00
# GO_KTSC_M       0.00
# GOK_TSC_F       0.00
# authorityM      0.00
# authorityF      0.00
# PTA_BOG_M       0.00
# PTA_BOG_F       0.00
# OthersM         0.00
# OthersF         0.00
# NoTeaching      0.00
# NonTeachin      0.00
# Province        0.00
# District        0.00
# Division        0.00
# Location        0.00
# Costituenc      0.00
# Latitude        0.00
# Longitude       0.00
# dtype: float64

# %%
school['Name_of_Sc']
# Out:
# 0            CHEBIREBEI PRI
# 1               WASEGES PRI
# 2               KIRIBOT PRI
# 3           KABUSWO PRI SCH
# 4        VONDENI PRI SCHOOL
#                 ...
# 31225          MGANGANI PRI
# 31226          KISIKINI PRI
# 31227       NGOMANO PRI SCH
# 31228           NGILUNI PRI
# 31229        KIKASO PRI SCH
# Name: Name_of_Sc, Length: 31230, dtype: object

# %%
school['Status']=school['Status'].fillna(school['Status'].mode()[0])

# %%
school['Status'].isnull().sum()
# Out:
# np.int64(0)

# %%
school['No_Classrm'].head(20)
# Out:
# 0      8.0
# 1      8.0
# 2      NaN
# 3      9.0
# 4     11.0
# 5      NaN
# 6      9.0
# 7      1.0
# 8      NaN
# 9      8.0
# 10     8.0
# 11     8.0
# 12     NaN
# 13     7.0
# 14     NaN
# 15     4.0
# 16    17.0
# 17     NaN
# 18     NaN
# 19     NaN
# Name: No_Classrm, dtype: float64

# %%
school['No_Classrm']=school['No_Classrm'].fillna(school['No_Classrm'].median())

# %%
school['No_Classrm'].isnull().sum()
# Out:
# np.int64(0)

# %%
school['TotalBoys']=school['TotalBoys'].fillna(school['TotalBoys'].median())
school['TotalGirls']=school['TotalGirls'].fillna(school['TotalGirls'].median())

# %%
school.isnull().sum()
# Out:
# X              0
# Y              0
# FID            0
# Name_of_Sc     1
# Level_         1
# Status         0
# SchSponsor     1
# Type1          1
# Type2          1
# Type3          1
# No_Classrm     0
# BoysToilet     1
# GirlsToilet    1
# TeachersTo     1
# TotalBoys      0
# TotalGirls     0
# TotalEnrol     1
# GO_KTSC_M      1
# GOK_TSC_F      1
# authorityM     1
# authorityF     1
# PTA_BOG_M      1
# PTA_BOG_F      1
# OthersM        1
# OthersF        1
# NoTeaching     1
# NonTeachin     1
# Province       1
# District       1
# Division       1
# Location       1
# Costituenc     1
# Latitude       1
# Longitude      1
# dtype: int64

# %%
clean_df=school.dropna()

# %%
clean_df.isnull().sum()
# Out:
# X              0
# Y              0
# FID            0
# Name_of_Sc     0
# Level_         0
# Status         0
# SchSponsor     0
# Type1          0
# Type2          0
# Type3          0
# No_Classrm     0
# BoysToilet     0
# GirlsToilet    0
# TeachersTo     0
# TotalBoys      0
# TotalGirls     0
# TotalEnrol     0
# GO_KTSC_M      0
# GOK_TSC_F      0
# authorityM     0
# authorityF     0
# PTA_BOG_M      0
# PTA_BOG_F      0
# OthersM        0
# OthersF        0
# NoTeaching     0
# NonTeachin     0
# Province       0
# District       0
# Division       0
# Location       0
# Costituenc     0
# Latitude       0
# Longitude      0
# dtype: int64

# %%
clean_df.head()
# Out:
#        X     Y    FID          Name_of_Sc          Level_  Status  \
# 0  36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1  36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2  36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3  36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4  37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
#
#                SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# 0  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 1  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 2               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 3               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 4               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
#
#    NoTeaching  NonTeachin     Province  District  Division  Location  \
# 0         0.0         0.0  RIFT VALLEY  KOIBATEK  KISANANA   MOGOTIO
# ...

# %%
clean_df.columns = clean_df.columns.str.lower().str.replace(' ', '_')
clean_df.head()
# Out:
#         x     y    fid         name_of_sc          level_   status  \
# 0   36.14  0.27  10001     CHEBIREBEI PRI  PRIMARY SCHOOL   PUBLIC
# 3   36.19  0.21  10004    KABUSWO PRI SCH  PRIMARY SCHOOL   PUBLIC
# 9   36.09  0.11  10010        CHOMIEK PRI  PRIMARY SCHOOL   PUBLIC
# 20  35.79  0.02  10021  GREENVIEW PRI SCH  PRIMARY SCHOOL  PRIVATE
# 22  35.76  0.00  10023         SOLIAN PRI  PRIMARY SCHOOL   PUBLIC
#
#                 schsponsor  type1     type2     type3  ...  othersf  \
# 0   RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 3                COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 9   RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 20      PRIVATE INDIVIDUAL  MIXED  DAY ONLY  ORDINARY  ...      2.0
# 22  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
#
#     noteaching  nonteachin     province  district  division       location  \
# ...

# %%
total_toilets=clean_df['boystoilet']+clean_df['girlstoilet']+clean_df['teachersto']
clean_df['total_toilets']=total_toilets
clean_df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5668\2302741635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['total_toilets']=total_toilets
#         x     y    fid         name_of_sc          level_   status  \
# 0   36.14  0.27  10001     CHEBIREBEI PRI  PRIMARY SCHOOL   PUBLIC
# 3   36.19  0.21  10004    KABUSWO PRI SCH  PRIMARY SCHOOL   PUBLIC
# 9   36.09  0.11  10010        CHOMIEK PRI  PRIMARY SCHOOL   PUBLIC
# 20  35.79  0.02  10021  GREENVIEW PRI SCH  PRIMARY SCHOOL  PRIVATE
# 22  35.76  0.00  10023         SOLIAN PRI  PRIMARY SCHOOL   PUBLIC
#
#                 schsponsor  type1     type2     type3  ...  noteaching  \
# 0   RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...         0.0
# ...
